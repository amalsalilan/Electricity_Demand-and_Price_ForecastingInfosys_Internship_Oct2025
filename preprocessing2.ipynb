# %%
import pandas as pd

# %%
df = pd.read_csv("updated_dataset.csv")

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2106 entries, 0 to 2105
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       2106 non-null   int64
#  1   date             2106 non-null   datetime64[ns]
#  2   demand           2106 non-null   float64
#  3   RRP              2106 non-null   float64
#  4   demand_pos_RRP   2106 non-null   float64
#  5   RRP_positive     2106 non-null   float64
#  6   demand_neg_RRP   2106 non-null   float64
#  7   RRP_negative     2106 non-null   float64
#  8   frac_at_neg_RRP  2106 non-null   float64
#  9   min_temperature  2106 non-null   float64
#  10  max_temperature  2106 non-null   float64
#  11  solar_exposure   2106 non-null   float64
#  12  rainfall         2106 non-null   float64
#  13  school_day       2106 non-null   int64
#  14  holiday          2106 non-null   int64
# dtypes: datetime64[ns](1), float64(11), int64(3)
# ...

# %%
df['weekday'] = df['date'].dt.weekday

# %%
df.head(10)
# Out:
#    Unnamed: 0       date      demand        RRP  demand_pos_RRP  RRP_positive  \
# 0           0 2015-01-01   99635.030  25.633696       97319.240     26.415953
# 1           1 2015-01-02  129606.010  33.138988      121082.015     38.837661
# 2           2 2015-01-03  142300.540  34.564855      142300.540     34.564855
# 3           3 2015-01-04  104330.715  25.005560      104330.715     25.005560
# 4           4 2015-01-05  118132.200  26.724176      118132.200     26.724176
# 5           5 2015-01-06  130672.485  31.282311      130672.485     31.282311
# 6           6 2015-01-07  153514.820  48.312309      149498.715     49.639712
# 7           7 2015-01-08  142015.655  49.117280      142015.655     49.117280
# 8           8 2015-01-09  121801.155  34.490675      121801.155     34.490675
# 9           9 2015-01-10  103043.660  20.229825      103043.660     20.229825
#
#    demand_neg_RRP  RRP_negative  frac_at_neg_RRP  min_temperature  \
# ...

# %%
df['school_day'] = df['weekday'].apply(lambda x: 1 if x < 5 else 0)

# %%
df.head(10)
# Out:
#    Unnamed: 0       date      demand        RRP  demand_pos_RRP  RRP_positive  \
# 0           0 2015-01-01   99635.030  25.633696       97319.240     26.415953
# 1           1 2015-01-02  129606.010  33.138988      121082.015     38.837661
# 2           2 2015-01-03  142300.540  34.564855      142300.540     34.564855
# 3           3 2015-01-04  104330.715  25.005560      104330.715     25.005560
# 4           4 2015-01-05  118132.200  26.724176      118132.200     26.724176
# 5           5 2015-01-06  130672.485  31.282311      130672.485     31.282311
# 6           6 2015-01-07  153514.820  48.312309      149498.715     49.639712
# 7           7 2015-01-08  142015.655  49.117280      142015.655     49.117280
# 8           8 2015-01-09  121801.155  34.490675      121801.155     34.490675
# 9           9 2015-01-10  103043.660  20.229825      103043.660     20.229825
#
#    demand_neg_RRP  RRP_negative  frac_at_neg_RRP  min_temperature  \
# ...

# %%
df.tail(10)
# Out:
#       Unnamed: 0       date      demand        RRP  demand_pos_RRP  \
# 2096        2096 2020-09-27  101703.490  57.920029      101703.490
# 2097        2097 2020-09-28  114651.140  59.746053      114651.140
# 2098        2098 2020-09-29  112076.460  42.120178      108164.360
# 2099        2099 2020-09-30  113620.210  38.057641      111746.460
# 2100        2100 2020-10-01  106641.790  34.654671       95349.610
# 2101        2101 2020-10-02   99585.835  -6.076028       41988.240
# 2102        2102 2020-10-03   92277.025  -1.983471       44133.510
# 2103        2103 2020-10-04   94081.565  25.008614       88580.995
# 2104        2104 2020-10-05  113610.030  36.764701      106587.375
# 2105        2105 2020-10-06  122607.560  75.771059      122607.560
#
#       RRP_positive  demand_neg_RRP  RRP_negative  frac_at_neg_RRP  \
# 2096     57.920029           0.000      0.000000         0.000000
# 2097     59.746053           0.000      0.000000         0.000000
# ...

# %%
public_holidays = [
    "2015-01-01", "2015-01-27", "2015-03-09", "2015-04-03", "2015-04-06", "2015-04-25", "2015-06-08", "2015-09-28", "2015-10-05", "2015-12-25", "2015-12-26", "2016-01-01", "2016-01-26", "2016-03-14", "2016-03-25", "2016-03-26", "2016-03-27", "2016-03-28", "2016-04-25", "2016-06-13", "2016-09-30", "2016-11-01", "2016-12-26", "2016-12-25", "2017-01-01", "2017-01-02", "2017-01-26", "2017-03-13", "2017-04-25", "2017-04-14", "2017-04-15", "2017-04-16", "2017-04-17", "2017-06-12", "2017-09-29", "2017-11-07", "2017-12-25", "2017-12-26", "2018-01-01", "2018-01-26", "2018-03-12", "2018-04-30", "2018-03-31", "2018-04-01", "2018-04-02", "2018-04-25", "2018-06-11", "2018-09-28", "2018-11-06", "2018-12-25", "2018-12-26", "2019-01-01", "2019-01-28", "2019-03-11", "2019-04-19", "2019-04-20", "2019-04-21", "2019-04-22", "2019-04-25", "2019-06-10", "2019-09-27", "2019-11-05", "2019-12-26", "2019-12-25", "2020-01-01", "2020-01-27", "2020-03-09", "2020-04-10", "2020-04-11", "2020-04-12", "2020-04-13", "2020-06-08"]

# %%
public_holidays = pd.to_datetime(public_holidays)

# %%
df['holiday'] = df['date'].isin(public_holidays).astype(int)

# %%
df.loc[df['weekday'] >= 5, 'holiday'] = 1

# %%
df.loc[df['holiday'] == 1, 'school_day'] = 0

# %%
df.head(20)
# Out:
#     Unnamed: 0       date      demand        RRP  demand_pos_RRP  \
# 0            0 2015-01-01   99635.030  25.633696       97319.240
# 1            1 2015-01-02  129606.010  33.138988      121082.015
# 2            2 2015-01-03  142300.540  34.564855      142300.540
# 3            3 2015-01-04  104330.715  25.005560      104330.715
# 4            4 2015-01-05  118132.200  26.724176      118132.200
# 5            5 2015-01-06  130672.485  31.282311      130672.485
# 6            6 2015-01-07  153514.820  48.312309      149498.715
# 7            7 2015-01-08  142015.655  49.117280      142015.655
# 8            8 2015-01-09  121801.155  34.490675      121801.155
# 9            9 2015-01-10  103043.660  20.229825      103043.660
# 10          10 2015-01-11   99865.755  18.234768       99865.755
# 11          11 2015-01-12  131261.125  33.694810      131261.125
# 12          12 2015-01-13  126527.360  27.537864      126527.360
# ...

# %%
# df.to_csv("final_dataset.csv")

# %%
df['school_day'].value_counts()
# Out:
# school_day
# 1    1446
# 0     660
# Name: count, dtype: int64

# %%
df['holiday'].value_counts()
# Out:
# holiday
# 0    1446
# 1     660
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2106 entries, 0 to 2105
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       2106 non-null   int64
#  1   date             2106 non-null   datetime64[ns]
#  2   demand           2106 non-null   float64
#  3   RRP              2106 non-null   float64
#  4   demand_pos_RRP   2106 non-null   float64
#  5   RRP_positive     2106 non-null   float64
#  6   demand_neg_RRP   2106 non-null   float64
#  7   RRP_negative     2106 non-null   float64
#  8   frac_at_neg_RRP  2106 non-null   float64
#  9   min_temperature  2106 non-null   float64
#  10  max_temperature  2106 non-null   float64
#  11  solar_exposure   2106 non-null   float64
#  12  rainfall         2106 non-null   float64
#  13  school_day       2106 non-null   int64
#  14  holiday          2106 non-null   int32
#  15  weekday          2106 non-null   int32
# ...
