# %%
import pandas as pd
file_path = "cleaned_dataset.csv"
df = pd.read_csv(file_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2106 entries, 0 to 2105
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             2106 non-null   object
#  1   demand           2106 non-null   float64
#  2   RRP              2106 non-null   float64
#  3   demand_pos_RRP   2106 non-null   float64
#  4   RRP_positive     2106 non-null   float64
#  5   demand_neg_RRP   2106 non-null   float64
#  6   RRP_negative     2106 non-null   float64
#  7   frac_at_neg_RRP  2106 non-null   float64
#  8   min_temperature  2106 non-null   float64
#  9   max_temperature  2106 non-null   float64
#  10  solar_exposure   2105 non-null   float64
#  11  rainfall         2103 non-null   float64
#  12  school_day       2106 non-null   object
#  13  holiday          2106 non-null   object
# dtypes: float64(11), object(3)
# memory usage: 230.5+ KB

# %%
df.isnull().sum()
# Out:
# date               0
# demand             0
# RRP                0
# demand_pos_RRP     0
# RRP_positive       0
# demand_neg_RRP     0
# RRP_negative       0
# frac_at_neg_RRP    0
# min_temperature    0
# max_temperature    0
# solar_exposure     1
# rainfall           3
# school_day         0
# holiday            0
# dtype: int64

# %%
df.loc[:, 'solar_exposure'] = df['solar_exposure'].fillna(df['solar_exposure'].median())
df.loc[:, 'rainfall'] = df['rainfall'].fillna(df['rainfall'].median())

df.isnull().sum()
# Out:
# date               0
# demand             0
# RRP                0
# demand_pos_RRP     0
# RRP_positive       0
# demand_neg_RRP     0
# RRP_negative       0
# frac_at_neg_RRP    0
# min_temperature    0
# max_temperature    0
# solar_exposure     0
# rainfall           0
# school_day         0
# holiday            0
# dtype: int64

# %% [markdown]
# **Filled the missing values using median**

# %%
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2106 entries, 0 to 2105
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             2106 non-null   datetime64[ns]
#  1   demand           2106 non-null   float64
#  2   RRP              2106 non-null   float64
#  3   demand_pos_RRP   2106 non-null   float64
#  4   RRP_positive     2106 non-null   float64
#  5   demand_neg_RRP   2106 non-null   float64
#  6   RRP_negative     2106 non-null   float64
#  7   frac_at_neg_RRP  2106 non-null   float64
#  8   min_temperature  2106 non-null   float64
#  9   max_temperature  2106 non-null   float64
#  10  solar_exposure   2106 non-null   float64
#  11  rainfall         2106 non-null   float64
#  12  school_day       2106 non-null   object
#  13  holiday          2106 non-null   object
# dtypes: datetime64[ns](1), float64(11), object(2)
# memory usage: 230.5+ KB

# %% [markdown]
# **Changed the date format**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
df['school_day'] = encoder.fit_transform(df['school_day'].astype(str))
df['holiday'] = encoder.fit_transform(df['holiday'].astype(str))
df.head()
# Out:
#         date      demand        RRP  demand_pos_RRP  RRP_positive  \
# 0 2015-01-01   99635.030  25.633696       97319.240     26.415953
# 1 2015-01-02  129606.010  33.138988      121082.015     38.837661
# 2 2015-01-03  142300.540  34.564855      142300.540     34.564855
# 3 2015-01-04  104330.715  25.005560      104330.715     25.005560
# 4 2015-01-05  118132.200  26.724176      118132.200     26.724176
#
#    demand_neg_RRP  RRP_negative  frac_at_neg_RRP  min_temperature  \
# 0        2315.790     -7.240000         0.020833             13.3
# 1        8523.995    -47.809777         0.062500             15.4
# 2           0.000      0.000000         0.000000             20.0
# 3           0.000      0.000000         0.000000             16.3
# 4           0.000      0.000000         0.000000             15.0
#
#    max_temperature  solar_exposure  rainfall  school_day  holiday
# 0             26.9            23.6       0.0           0        1
# ...

# %%
df.tail()
# Out:
#            date      demand        RRP  demand_pos_RRP  RRP_positive  \
# 2101 2020-10-02   99585.835  -6.076028       41988.240     26.980251
# 2102 2020-10-03   92277.025  -1.983471       44133.510     32.438156
# 2103 2020-10-04   94081.565  25.008614       88580.995     26.571687
# 2104 2020-10-05  113610.030  36.764701      106587.375     39.616015
# 2105 2020-10-06  122607.560  75.771059      122607.560     75.771059
#
#       demand_neg_RRP  RRP_negative  frac_at_neg_RRP  min_temperature  \
# 2101       57597.595    -30.173823         0.625000             12.8
# 2102       48143.515    -33.538025         0.583333             17.4
# 2103        5500.570     -0.163066         0.062500             13.5
# 2104        7022.655     -6.511550         0.083333              9.1
# 2105           0.000      0.000000         0.000000              8.9
#
#       max_temperature  solar_exposure  rainfall  school_day  holiday
# ...

# %% [markdown]
# Changed the object type data(school day and holiday) to numerical data using **Label Encoding**.

# %%
df.to_csv("cleaned_data.csv", index=False)

# %%
import pandas as pd
file_path = "cleaned_data.csv"
df = pd.read_csv(file_path)

# %%
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2106 entries, 0 to 2105
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             2106 non-null   datetime64[ns]
#  1   demand           2106 non-null   float64
#  2   RRP              2106 non-null   float64
#  3   demand_pos_RRP   2106 non-null   float64
#  4   RRP_positive     2106 non-null   float64
#  5   demand_neg_RRP   2106 non-null   float64
#  6   RRP_negative     2106 non-null   float64
#  7   frac_at_neg_RRP  2106 non-null   float64
#  8   min_temperature  2106 non-null   float64
#  9   max_temperature  2106 non-null   float64
#  10  solar_exposure   2106 non-null   float64
#  11  rainfall         2106 non-null   float64
#  12  school_day       2106 non-null   int64
#  13  holiday          2106 non-null   int64
# dtypes: datetime64[ns](1), float64(11), int64(2)
# memory usage: 230.5 KB

# %%
df.to_csv("cleaned_data.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2106 entries, 0 to 2105
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             2106 non-null   datetime64[ns]
#  1   demand           2106 non-null   float64
#  2   RRP              2106 non-null   float64
#  3   demand_pos_RRP   2106 non-null   float64
#  4   RRP_positive     2106 non-null   float64
#  5   demand_neg_RRP   2106 non-null   float64
#  6   RRP_negative     2106 non-null   float64
#  7   frac_at_neg_RRP  2106 non-null   float64
#  8   min_temperature  2106 non-null   float64
#  9   max_temperature  2106 non-null   float64
#  10  solar_exposure   2106 non-null   float64
#  11  rainfall         2106 non-null   float64
#  12  school_day       2106 non-null   int64
#  13  holiday          2106 non-null   int64
# dtypes: datetime64[ns](1), float64(11), int64(2)
# memory usage: 230.5 KB

# %% [markdown]
# **Changed the date format**

# %%
df.head(40)
# Out:
#          date      demand        RRP  demand_pos_RRP  RRP_positive  \
# 0  2015-01-01   99635.030  25.633696       97319.240     26.415953
# 1  2015-01-02  129606.010  33.138988      121082.015     38.837661
# 2  2015-01-03  142300.540  34.564855      142300.540     34.564855
# 3  2015-01-04  104330.715  25.005560      104330.715     25.005560
# 4  2015-01-05  118132.200  26.724176      118132.200     26.724176
# 5  2015-01-06  130672.485  31.282311      130672.485     31.282311
# 6  2015-01-07  153514.820  48.312309      149498.715     49.639712
# 7  2015-01-08  142015.655  49.117280      142015.655     49.117280
# 8  2015-01-09  121801.155  34.490675      121801.155     34.490675
# 9  2015-01-10  103043.660  20.229825      103043.660     20.229825
# 10 2015-01-11   99865.755  18.234768       99865.755     18.234768
# 11 2015-01-12  131261.125  33.694810      131261.125     33.694810
# 12 2015-01-13  126527.360  27.537864      126527.360     27.537864
# ...
